# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaish48/ML/blob/main/ML_LAB_4(3rd_experiment).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

data = pd.read_csv("TvMarketing.csv")
print(data.head())
print(data.info())
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB
# None

# %%
plt.scatter(data['TV'], data['Sales'])
plt.xlabel("TV Budget")
plt.ylabel("Sales")
plt.title("TV Budget vs Sales")
plt.show()

# %%
X = data[['TV']]
y = data['Sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print("Training shape:", X_train.shape)
print("Testing shape:", X_test.shape)
# Out:
# Training shape: (160, 1)
# Testing shape: (40, 1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

b0 = model.intercept_
b1 = model.coef_[0]

print("Intercept:", b0)
print("Slope:", b1)
# Out:
# Intercept: 6.996501024621748
# Slope: 0.048882301241446866

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red')
plt.title("Best Fit Line")
plt.show()

# %%
y_pred = model.predict(X_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
# Out:
#      Actual  Predicted
# 77     14.2  12.886818
# 121     7.0   7.915488
# 167    12.2  17.105361
# 30     21.4  21.314127
# 171    14.5  15.037640
# 176    20.2  19.138865
# 10      8.6  10.227621
# 48     14.8  18.102560
# 107     8.7  11.415461
# 38     10.1   9.103328
# 26     15.0  13.981782
# 139    20.7  16.034839
# 25     12.0  19.847658
# 177    11.7  15.316269
# 117     9.4  10.731109
# 82     11.3  10.677338
# 72      8.8   8.306547
# 190    10.8   8.927352
# 12      9.2   8.159900
# 147    25.4  18.884677
# 182     8.7   9.743686
# 169    15.0  20.893739
# 149    10.1   9.181540
# 65      9.3  10.369380
# 195     7.6   8.863805
# 179    12.6  15.091410
# 5       7.2   7.421777
# 8       4.8   7.416889
# 6      11.8   9.807233
# 33     17.4  19.979640
# 97     15.5  16.034839
# 46     10.6  11.381243
# 39     21.5  18.141666
# 60      8.1   9.611704
# 13      9.7  11.762525
# 134    10.8   8.800258
# 138     9.6   9.098440
# 49      9.7  10.266727
# 81     12.3  18.718477
# 96     11.7  16.655644

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# RMSE: 2.9540495244351175
# R2 Score: 0.567174635180153

# %%
import seaborn as sns

data = pd.read_csv("DATA.csv")
print(data.head())
print(data.info())
# Out:
#           Car       Model  Volume  Weight  CO2  Unnamed: 5
# 0      Toyota        Aygo    1000     790   99         NaN
# 1  Mitsubishi  Space Star    1200    1160   95         NaN
# 2       Skoda      Citigo    1000     929   95         NaN
# 3        Fiat         500     900     865   90         NaN
# 4        Mini      Cooper    1500    1140  105         NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Car         36 non-null     object
#  1   Model       36 non-null     object
#  2   Volume      36 non-null     int64
#  3   Weight      36 non-null     int64
#  4   CO2         36 non-null     int64
#  5   Unnamed: 5  0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.8+ KB
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3723907259.py in <cell line: 0>()
#       5 print(data.info())
#       6
# ----> 7 corr = data[['VOLUME','WEIGHT','CO2']].corr()
#       8 print(corr)
#       9
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252             raise KeyError(f"{not_found} not in index")
#    6253
#    6254     @overload
#
# KeyError: "['VOLUME', 'WEIGHT'] not in index"
